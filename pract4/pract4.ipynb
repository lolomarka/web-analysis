# %%
from selenium import webdriver
import time
from selenium.webdriver import FirefoxOptions

# %%
def fetch_page(url):
    options = FirefoxOptions()
    options.add_argument('--headless')
    browser = webdriver.Firefox()
    try:
        browser.get(url)
        time.sleep(5)
        return browser.page_source
    finally:
        browser.quit()

# %%
# print(fetch_page("https://rutube.ru"))

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
def find_a_hrefs(soup : BeautifulSoup, base_url : str, links : set) -> None:
    for a in soup.find_all('a', href=True):
            href = a['href']
            if href.startswith('/video/'):
                links.add(urljoin(base_url, href))

# %%
def find_videos(soup : BeautifulSoup, base_url : str, links : set) -> None:
    for video in soup.find_all('video'):
        src = video.get('src')
        if src:
            links.add(urljoin(base_url, src))

# %%
def find_video_links(page_source, base_url) -> set:
    soup = BeautifulSoup(page_source, 'html.parser')
    links = set()
    find_a_hrefs(soup, base_url, links)
    find_videos(soup, base_url, links)
    return links

# url = "https://rutube.ru"
# find_video_links(fetch_page(url),url)
# Out:
# {'https://rutube.ru/video/068c079224409a2160fb4dd86227f147/',
#  'https://rutube.ru/video/0693b46b7c474bdaed48028bbc5a7a7b/',
#  'https://rutube.ru/video/07893625ddd5efa12cff680f112aa888/',
#  'https://rutube.ru/video/0a80791ce1196a4f3c8c0b02d0a05f19/',
#  'https://rutube.ru/video/0b407a93cc9cd563e1f55b518d3a1166/',
#  'https://rutube.ru/video/0d11dd5f87902f6eb116457214fd4512/',
#  'https://rutube.ru/video/0dac528294919dc37f7baec50d284c28/',
#  'https://rutube.ru/video/1093f29f9667ec03a98d36cca70da991/',
#  'https://rutube.ru/video/10d4d9dac5f97b2b35081789da81c480/',
#  'https://rutube.ru/video/113d2b6f054110ab716781a8a9a56df4/',
#  'https://rutube.ru/video/11babf8f6ea28ba89f6484e2e158f0e0/',
#  'https://rutube.ru/video/12fd18685396da76d5156d0903124178/',
#  'https://rutube.ru/video/1312f78f7428613696f13f9cc63123c2/',
#  'https://rutube.ru/video/13a6a04b7582fb16f755ff0fbb8c250c/',
#  'https://rutube.ru/video/18f583b8c5eed021f1c05798579e0f92/',
#  'https://rutube.ru/video/1d30146673ebbf0c72d73cbae37c21ea/',
#  'https://rutube.ru/video/212d38da934fe70b8563a9f964780e96/',
#  'https://rutube.ru/video/21943e8dbacd7a9ce34181dcd4ecfd08/',
#  'https://rutube.ru/video/238d864d31a7f2bf4fc3207460195a69/',
#  'https://rutube.ru/video/23ad2dc5d79da2875cd1d6b3ade5a1df/',
#  'https://rutube.ru/video/250941dd14ff6ca7252fbb43867e283b/',
#  'https://rutube.ru/video/2566377158bba18cf362fd1457425ea4/',
#  'https://rutube.ru/video/274ddb79d80f818e420fe25cd2070d14/',
#  'https://rutube.ru/video/28312cc0b564ac9f7304a9ef4dd36f29/',
#  'https://rutube.ru/video/2831fce43365704add3656e1c9874674/',
#  'https://rutube.ru/video/2b2dbc99cf58ad7f9bc37dcde4592fce/',
#  'https://rutube.ru/video/2b4b3ba4b583682fdb35480fcb837eb1/',
#  'https://rutube.ru/video/2c01c1c4623c9617a95d009b3e5c697d/',
#  'https://rutube.ru/video/person/42349178/',
#  'https://rutube.ru/video/person/42354004/',
#  'https://rutube.ru/video/person/42612929/',
#  'https://rutube.ru/video/person/42944249/',
#  'https://rutube.ru/video/person/43033342/',
#  'https://rutube.ru/video/person/43178031/',
#  'https://rutube.ru/video/person/43392194/',
#  'https://rutube.ru/video/person/43728229/',
#  'https://rutube.ru/video/person/44045648/',
#  'https://rutube.ru/video/person/44097944/',
#  'https://rutube.ru/video/person/44118459/',
#  'https://rutube.ru/video/person/44162264/',
#  'https://rutube.ru/video/person/44554917/',
#  'https://rutube.ru/video/person/44823995/',
#  'https://rutube.ru/video/person/45874977/',
#  'https://rutube.ru/video/person/46653598/',
#  'https://rutube.ru/video/person/48922187/',
#  'https://rutube.ru/video/person/49311190/',
#  'https://rutube.ru/video/person/49619694/',
#  'https://rutube.ru/video/person/49715131/',
#  'https://rutube.ru/video/person/5518074/',
#  'https://rutube.ru/video/person/604253/',
#  'https://rutube.ru/video/person/6558523/',
#  'https://rutube.ru/video/person/7456516/',
#  'https://rutube.ru/video/person/755352/',
#  'https://rutube.ru/video/person/8227896/',
#  'https://rutube.ru/video/person/929618/'}

# %%
import yt_dlp
import os

def download_video(video_url : str, save_directory : str) -> None:
    opts = {
        'outtmpl' : os.path.join(save_directory, f'video_%(title)s.%(ext)s'),
        'writeinfojson' : True,
        'writethumnail' : True,
        'merge_output_format' : 'mp4'
    }

    with yt_dlp.YoutubeDL(opts) as ydl:
        ydl.download([video_url])

    print("Video from {video_url} downloaded.")

def fetch_video(url):
    try:
        page_source = fetch_page(url)
        directory_suffix = url.replace('://', '_').replace('/', '_')
        directory = f'videos_{directory_suffix}'

        os.makedirs(directory, exist_ok=True)

        links = find_video_links(page_source, url)
        
        if not links:
            print('Has no videos on page: {url}')
        else:
            for video_url in links:
                try:
                    download_video(video_url, directory)
                except Exception as ex:
                    print(f'Exception was thrown by download {url}. \n\t Exception: {ex}')
        
    except Exception as ex:
        print("Page {url} processing exception: {ex}")

# %%
fetch_video('https://rutube.ru')
# Out:
# [rutube:person] Extracting URL: https://rutube.ru/video/person/43728229/
# [download] Downloading playlist: 43728229
# [rutube:person] 43728229: Downloading page 1
# [rutube:person] 43728229: Downloading page 2
# [rutube:person] 43728229: Downloading page 3
# [rutube:person] 43728229: Downloading page 4
# [info] Writing playlist metadata as JSON to: videos_https_rutube.ru/video_NA.info.json
# [rutube:person] Playlist 43728229: Downloading 68 items of 68
# [download] Downloading item 1 of 68
# [rutube] Extracting URL: https://rutube.ru/video/29db3ffc655ab1ba33182117303b9de0/
# [rutube] 29db3ffc655ab1ba33182117303b9de0: Downloading video JSON
# [rutube] 29db3ffc655ab1ba33182117303b9de0: Downloading options JSON
# [rutube] 29db3ffc655ab1ba33182117303b9de0: Downloading m3u8 information
# [rutube] 29db3ffc655ab1ba33182117303b9de0: Downloading m3u8 information
# [info] 29db3ffc655ab1ba33182117303b9de0: Downloading 1 format(s): m3u8-2974-1
# [info] Writing video metadata as JSON to: videos_https_rutube.ru/video_Научись скорей читать! Хелен и Томас Докерти.info.json
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 148
# [download] Destination: videos_https_rutube.ru/video_Научись скорей читать! Хелен и Томас Докерти.mp4
# [download] 100% of  215.58MiB in 00:00:30 at 7.09MiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "videos_https_rutube.ru/video_Научись скорей читать! Хелен и Томас Докерти.mp4"
# [download] Downloading item 2 of 68
# [rutube] Extracting URL: https://rutube.ru/video/8b28ae7a75b1713770348e8cedf07364/
# [rutube] 8b28ae7a75b1713770348e8cedf07364: Downloading video JSON
# [rutube] 8b28ae7a75b1713770348e8cedf07364: Downloading options JSON
# [rutube] 8b28ae7a75b1713770348e8cedf07364: Downloading m3u8 information
# [rutube] 8b28ae7a75b1713770348e8cedf07364: Downloading m3u8 information
# [info] 8b28ae7a75b1713770348e8cedf07364: Downloading 1 format(s): m3u8-871-1
# [info] Writing video metadata as JSON to: videos_https_rutube.ru/video_Новый день  Новая история.info.json
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 12
# [download] Destination: videos_https_rutube.ru/video_Новый день  Новая история.mp4
# [download] 100% of    4.81MiB in 00:00:01 at 4.58MiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "videos_https_rutube.ru/video_Новый день  Новая история.mp4"
# [download] Downloading item 3 of 68
# [rutube] Extracting URL: https://rutube.ru/video/9db60372f84d8278d1a84294b9defd60/
# [rutube] 9db60372f84d8278d1a84294b9defd60: Downloading video JSON
# [rutube] 9db60372f84d8278d1a84294b9defd60: Downloading options JSON
# [rutube] 9db60372f84d8278d1a84294b9defd60: Downloading m3u8 information
# [rutube] 9db60372f84d8278d1a84294b9defd60: Downloading m3u8 information
# [info] 9db60372f84d8278d1a84294b9defd60: Downloading 1 format(s): m3u8-1525-1
# [info] Writing video metadata as JSON to: videos_https_rutube.ru/video_Бонни Беккер. Медведь в библиотеке.info.json
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 105
# [download] Destination: videos_https_rutube.ru/video_Бонни Беккер. Медведь в библиотеке.mp4
# [download] 100% of   78.77MiB in 00:00:11 at 6.79MiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "videos_https_rutube.ru/video_Бонни Беккер. Медведь в библиотеке.mp4"
# [download] Downloading item 4 of 68
# [rutube] Extracting URL: https://rutube.ru/video/5f1b504b6c8476646a193becd2df6c13/
# [rutube] 5f1b504b6c8476646a193becd2df6c13: Downloading video JSON
# [rutube] 5f1b504b6c8476646a193becd2df6c13: Downloading options JSON
# [rutube] 5f1b504b6c8476646a193becd2df6c13: Downloading m3u8 information
# [rutube] 5f1b504b6c8476646a193becd2df6c13: Downloading m3u8 information
# [info] 5f1b504b6c8476646a193becd2df6c13: Downloading 1 format(s): m3u8-1647-1
# [info] Writing video metadata as JSON to: videos_https_rutube.ru/video_Рей Бредбери. Всё лето в один день.info.json
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 157
# [download] Destination: videos_https_rutube.ru/video_Рей Бредбери. Всё лето в один день.mp4
# [download] 100% of  192.11MiB in 00:00:24 at 7.79MiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "videos_https_rutube.ru/video_Рей Бредбери. Всё лето в один день.mp4"
# [download] Downloading item 5 of 68
# [rutube] Extracting URL: https://rutube.ru/video/3ed63dd6c7f9a5ca44fb755087d8ff15/
# [rutube] 3ed63dd6c7f9a5ca44fb755087d8ff15: Downloading video JSON
# [rutube] 3ed63dd6c7f9a5ca44fb755087d8ff15: Downloading options JSON
# [rutube] 3ed63dd6c7f9a5ca44fb755087d8ff15: Downloading m3u8 information
# [rutube] 3ed63dd6c7f9a5ca44fb755087d8ff15: Downloading m3u8 information
# [info] 3ed63dd6c7f9a5ca44fb755087d8ff15: Downloading 1 format(s): m3u8-640-1
# [info] Writing video metadata as JSON to: videos_https_rutube.ru/video_Терехов. Соколиная дорога.info.json
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 102
# [download] Destination: videos_https_rutube.ru/video_Терехов. Соколиная дорога.mp4
# [download] 100% of   50.28MiB in 00:00:08 at 5.76MiB/s
# [FixupM3u8] Fixing MPEG-TS in MP4 container of "videos_https_rutube.ru/video_Терехов. Соколиная дорога.mp4"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 fetch_video('https://rutube.ru')
#
# Cell In[25], line 32, in fetch_video(url)
#      30 for video_url in links:
#      31     try:
# ---> 32         download_video(video_url, directory)
#      33     except Exception as ex:
#      34         print(f'Exception was thrown by download {url}. \n\t Exception: {ex}')
#
# Cell In[25], line 13, in download_video(video_url, save_directory)
#       5 opts = {
#       6     'outtmpl' : os.path.join(save_directory, f'video_%(title)s.%(ext)s'),
#       7     'writeinfojson' : True,
#       8     'writethumnail' : True,
#       9     'merge_output_format' : 'mp4'
#      10 }
#      12 with yt_dlp.YoutubeDL(opts) as ydl:
# ---> 13     ydl.download([video_url])
#      15 print("Video from {video_url} downloaded.")
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3604, in YoutubeDL.download(self, url_list)
#    3601     raise SameFileError(outtmpl)
#    3603 for url in url_list:
# -> 3604     self.__download_wrapper(self.extract_info)(
#    3605         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3607 return self._download_retcode
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3577, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3574 @functools.wraps(func)
#    3575 def wrapper(*args, **kwargs):
#    3576     try:
# -> 3577         res = func(*args, **kwargs)
#    3578     except CookieLoadError:
#    3579         raise
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1613, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1611             raise ExistingVideoReached
#    1612         break
# -> 1613     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1614 else:
#    1615     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1624, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1622 while True:
#    1623     try:
# -> 1624         return func(self, *args, **kwargs)
#    1625     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1626         raise
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1780, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1778 if process:
#    1779     self._wait_for_video(ie_result)
# -> 1780     return self.process_ie_result(ie_result, download, extra_info)
#    1781 else:
#    1782     return ie_result
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1909, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1907 self._sanitize_thumbnails(ie_result)
#    1908 try:
# -> 1909     return self.__process_playlist(ie_result, download)
#    1910 finally:
#    1911     self._playlist_level -= 1
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:2056, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2050     continue
#    2052 self.to_screen(
#    2053     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2054     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2056 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2057     'playlist_index': playlist_index,
#    2058     'playlist_autonumber': i + 1,
#    2059 }, extra))
#    2060 if not entry_result:
#    2061     failures += 1
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1624, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1622 while True:
#    1623     try:
# -> 1624         return func(self, *args, **kwargs)
#    1625     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1626         raise
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:2088, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2086 @_handle_extraction_exceptions
#    2087 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2088     return self.process_ie_result(
#    2089         entry, download=download, extra_info=extra_info)
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1859, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1855     return ie_result
#    1856 elif result_type == 'url':
#    1857     # We have to add extra_info to the results because it may be
#    1858     # contained in a playlist
# -> 1859     return self.extract_info(
#    1860         ie_result['url'], download,
#    1861         ie_key=ie_result.get('ie_key'),
#    1862         extra_info=extra_info)
#    1863 elif result_type == 'url_transparent':
#    1864     # Use the information from the embedding page
#    1865     info = self.extract_info(
#    1866         ie_result['url'], ie_key=ie_result.get('ie_key'),
#    1867         extra_info=extra_info, download=False, process=False)
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1613, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1611             raise ExistingVideoReached
#    1612         break
# -> 1613     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1614 else:
#    1615     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1624, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1622 while True:
#    1623     try:
# -> 1624         return func(self, *args, **kwargs)
#    1625     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1626         raise
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1780, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1778 if process:
#    1779     self._wait_for_video(ie_result)
# -> 1780     return self.process_ie_result(ie_result, download, extra_info)
#    1781 else:
#    1782     return ie_result
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:1839, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1837 if result_type == 'video':
#    1838     self.add_extra_info(ie_result, extra_info)
# -> 1839     ie_result = self.process_video_result(ie_result, download=download)
#    1840     self._raise_pending_errors(ie_result)
#    1841     additional_urls = (ie_result or {}).get('additional_urls')
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3010, in YoutubeDL.process_video_result(self, info_dict, download)
#    3008 downloaded_formats.append(new_info)
#    3009 try:
# -> 3010     self.process_info(new_info)
#    3011 except MaxDownloadsReached:
#    3012     max_downloads_reached = True
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:177, in _catch_unsafe_extension_error.<locals>.wrapper(self, *args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(self, *args, **kwargs):
#     176     try:
# --> 177         return func(self, *args, **kwargs)
#     178     except _UnsafeExtensionError as error:
#     179         self.report_error(
#     180             f'The extracted extension ({error.extension!r}) is unusual '
#     181             'and will be skipped for safety reasons. '
#     182             f'If you believe this is an error{bug_reports_message(",")}')
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3556, in YoutubeDL.process_info(self, info_dict)
#    3554 fixup()
#    3555 try:
# -> 3556     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3557 except PostProcessingError as err:
#    3558     self.report_error(f'Postprocessing: {err}')
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3740, in YoutubeDL.post_process(self, filename, info, files_to_move)
#    3738 info['filepath'] = filename
#    3739 info['__files_to_move'] = files_to_move or {}
# -> 3740 info = self.run_all_pps('post_process', info, additional_pps=info.get('__postprocessors'))
#    3741 info = self.run_pp(MoveFilesAfterDownloadPP(self), info)
#    3742 del info['__files_to_move']
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3722, in YoutubeDL.run_all_pps(self, key, info, additional_pps)
#    3720     self._forceprint(key, info)
#    3721 for pp in (additional_pps or []) + self._pps[key]:
# -> 3722     info = self.run_pp(pp, info)
#    3723 return info
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/YoutubeDL.py:3700, in YoutubeDL.run_pp(self, pp, infodict)
#    3698     infodict['__files_to_move'] = {}
#    3699 try:
# -> 3700     files_to_delete, infodict = pp.run(infodict)
#    3701 except PostProcessingError as e:
#    3702     # Must be True and not 'only_download'
#    3703     if self.params.get('ignoreerrors') is True:
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/postprocessor/common.py:22, in PostProcessorMetaClass.run_wrapper.<locals>.run(self, info, *args, **kwargs)
#      20 info_copy = self._copy_infodict(info)
#      21 self._hook_progress({'status': 'started'}, info_copy)
# ---> 22 ret = func(self, info, *args, **kwargs)
#      23 if ret is not None:
#      24     _, info = ret
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/postprocessor/common.py:127, in PostProcessor._restrict_to.<locals>.decorator.<locals>.wrapper(self, info)
#     122 format_type = (
#     123     'video' if info.get('vcodec') != 'none'
#     124     else 'audio' if info.get('acodec') != 'none'
#     125     else 'images')
#     126 if allowed[format_type]:
# --> 127     return func(self, info)
#     128 else:
#     129     self.to_screen(f'Skipping {format_type}')
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/postprocessor/ffmpeg.py:905, in FFmpegFixupM3u8PP.run(self, info)
#     903     if self.get_audio_codec(info['filepath']) == 'aac':
#     904         args.extend(['-bsf:a', 'aac_adtstoasc'])
# --> 905     self._fixup('Fixing MPEG-TS in MP4 container', info['filepath'], [
#     906         *self.stream_copy_opts(), *args])
#     907 return [], info
#
# File ~/Documents/web-analysis/.venv/lib64/python3.13/site-packages/yt_dlp/postprocessor/ffmpeg.py:866, in FFmpegFixupPostProcessor._fixup(self, msg, filename, options)
#     863 self.to_screen(f'{msg} of "{filename}"')
#     864 self.run_ffmpeg(filename, temp_filename, options)
# --> 866 os.replace(temp_filename, filename)
#
# KeyboardInterrupt:
